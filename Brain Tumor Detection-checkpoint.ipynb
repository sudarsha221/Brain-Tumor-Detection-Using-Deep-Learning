# %%
import os

IMG_PATH = 'C:\\Users\\Guru\\brain tumor detection model\\data set\\'

for CLASS in os.listdir(IMG_PATH):
    class_path = os.path.join(IMG_PATH, CLASS)
    if not CLASS.startswith('.') and os.path.isdir(class_path):
        IMG_NUM = len(os.listdir(class_path))
        print(f"Class: {CLASS} -> Total Images: {IMG_NUM}")
# Out:
# Class: glioma -> Total Images: 710
# Class: meningioma -> Total Images: 710
# Class: no tumor -> Total Images: 710
# Class: pituitary -> Total Images: 710

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

IMG_PATH = 'C:\\Users\\Guru\\brain tumor detection model\\data set\\'
IMG_EXT = ('.png', '.jpg', '.jpeg')

# Get valid class folders
class_folders = sorted([f for f in os.listdir(IMG_PATH) 
                        if not f.startswith('.') and os.path.isdir(os.path.join(IMG_PATH, f))])

# Set up the plot grid
cols = 4  # you can change this depending on how many folders you have
rows = (len(class_folders) + cols - 1) // cols
plt.figure(figsize=(4 * cols, 4 * rows))

for idx, class_name in enumerate(class_folders):
    class_path = os.path.join(IMG_PATH, class_name)
    image_files = [f for f in os.listdir(class_path) if f.lower().endswith(IMG_EXT)]

    if image_files:
        image_path = os.path.join(class_path, image_files[0])
        img = mpimg.imread(image_path)

        plt.subplot(rows, cols, idx + 1)
        plt.imshow(img)
        plt.title(class_name)
        plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
#  # PREPROCESSING

# %%
import os
import shutil
import random

SOURCE_DIR = 'C:\\Users\\Guru\\brain tumor detection model\\data set'
DEST_DIR = 'C:\\Users\\Guru\\brain tumor detection model\\dataset_split'

split_ratio = 0.8  # 80% train, 20% test

# Make train/test directories
for split in ['train', 'test']:
    for class_name in os.listdir(SOURCE_DIR):
        class_path = os.path.join(DEST_DIR, split, class_name)
        os.makedirs(class_path, exist_ok=True)

# Split files
for class_name in os.listdir(SOURCE_DIR):
    class_path = os.path.join(SOURCE_DIR, class_name)
    if not os.path.isdir(class_path):
        continue

    files = os.listdir(class_path)
    random.shuffle(files)

    split_index = int(len(files) * split_ratio)
    train_files = files[:split_index]
    test_files = files[split_index:]

    # Copy train files
    for file in train_files:
        src = os.path.join(class_path, file)
        dst = os.path.join(DEST_DIR, 'train', class_name, file)
        shutil.copy2(src, dst)

    # Copy test files
    for file in test_files:
        src = os.path.join(class_path, file)
        dst = os.path.join(DEST_DIR, 'test', class_name, file)
        shutil.copy2(src, dst)

    # ✅ Print image count per class
    print(f"\nClass: {class_name}")
    print(f"  Total Images: {len(files)}")
    print(f"  Train Images: {len(train_files)}")
    print(f"  Test Images:  {len(test_files)}")

print("\n✅ Dataset successfully split into train and test sets.")
# Out:
# Class: glioma
#   Total Images: 710
#   Train Images: 568
#   Test Images:  142
#
# Class: meningioma
#   Total Images: 710
#   Train Images: 568
#   Test Images:  142
#
# Class: no tumor
#   Total Images: 710
#   Train Images: 568
#   Test Images:  142
#
# Class: pituitary
#   Total Images: 710
#   Train Images: 568
#   Test Images:  142
#
# ✅ Dataset successfully split into train and test sets.

# %% [markdown]
# # AUGMENTED

# %%
import os
import random
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

train_dir = 'C:\\Users\\Guru\\brain tumor detection model\\dataset_split\\train'
TARGET_IMAGES_PER_CLASS = 4544
IMAGE_SIZE = (240, 240)

# Data augmentation settings
datagen = ImageDataGenerator(
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# Loop over each class
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)
    if not os.path.isdir(class_path):
        continue

    print(f"\nClass: {class_name}")

    # Repeat until exactly 4544 images are reached
    while True:
        image_files = [f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        current_count = len(image_files)
        print(f"  Current images: {current_count}", end='\r')

        if current_count >= TARGET_IMAGES_PER_CLASS:
            break

        # Randomly pick one image to augment
        img_name = random.choice(image_files)
        img_path = os.path.join(class_path, img_name)

        try:
            img = load_img(img_path, target_size=IMAGE_SIZE)
            x = img_to_array(img)
            x = x.reshape((1,) + x.shape)

            # Generate one augmented image and save it
            for batch in datagen.flow(x, batch_size=1, save_to_dir=class_path,
                                      save_prefix='aug', save_format='jpg'):
                break  # Only one image needed at a time
        except Exception as e:
            print(f"  ⚠️ Error processing {img_name}: {e}")
            continue

    final_count = len([f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
    print(f"  ✅ Final count for {class_name}: {final_count} images")

print("\n🎯 All classes now contain exactly 4544 images.")
# Out:
# Class: glioma
#   ✅ Final count for glioma: 4544 images
#
# Class: meningioma
#   ✅ Final count for meningioma: 4544 images
#
# Class: no tumor
#   ✅ Final count for no tumor: 4544 images
#
# Class: pituitary
#   ✅ Final count for pituitary: 4544 images
#
# 🎯 All classes now contain exactly 4544 images.

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img
import tensorflow as tf

# Helper to apply augmentations manually
def apply_augmentation(image, aug_type):
    image = tf.convert_to_tensor(image)

    if aug_type == 'original':
        return image
    elif aug_type == 'rotate +25°':
        return tf.image.rot90(image, k=1)  # 90 degrees
    elif aug_type == 'rotate -25°':
        return tf.image.rot90(image, k=3)  # -90 degrees
    elif aug_type == 'horizontal flip':
        return tf.image.flip_left_right(image)
    elif aug_type == 'vertical flip':
        return tf.image.flip_up_down(image)
    elif aug_type == 'zoom in':
        crop = tf.image.central_crop(image, 0.7)
        return tf.image.resize(crop, size=(240, 240))
    elif aug_type == 'width shift':
        return tf.roll(image, shift=20, axis=1)
    elif aug_type == 'height shift':
        return tf.roll(image, shift=20, axis=0)
    else:
        return image

# Define all augmentation labels
AUGMENTATIONS = [
    'original',
    'rotate +25°',
    'rotate -25°',
    'horizontal flip',
    'vertical flip',
    'zoom in',
    'width shift',
    'height shift'
]

# Paths
train_dir = 'C:\\Users\\Guru\\brain tumor detection model\\dataset_split\\train'
IMAGE_SIZE = (240, 240)

# Get class folders
class_names = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]

# Process one image from each class
for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    image_files = [f for f in os.listdir(class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    if not image_files:
        print(f"No images found in {class_name}")
        continue

    img_path = os.path.join(class_path, image_files[0])
    img = load_img(img_path, target_size=IMAGE_SIZE)
    img_array = img_to_array(img)

    plt.figure(figsize=(15, 6))
    plt.suptitle(f'{class_name.upper()} - Augmented Variations', fontsize=16)

    for i, aug_type in enumerate(AUGMENTATIONS):
        aug_img = apply_augmentation(img_array, aug_type)
        aug_img = tf.cast(aug_img, tf.uint8).numpy()

        plt.subplot(2, 4, i + 1)
        plt.imshow(aug_img)
        plt.title(aug_type, fontsize=10)
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization, GlobalAveragePooling2D, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# # Step 1: Load VGG16 base model without top layers

# %%
 base_model = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# %% [markdown]
# # Step 2: Freeze base model layers to prevent training them

# %%
 for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# # Step 3: Add custom classification layers on top

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)  # or Flatten()(x) if you prefer
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(4, activation='softmax')(x)  # For 3-class classification (e.g., tumor types)

# %% [markdown]
# # Step 4: Combine base and custom layers into one model

# %%
model = Model(inputs=base_model.input, outputs=output)

# %% [markdown]
# # Step 5: compile the model

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
print(model.output_shape)
# Out:
# (None, 4)

# %%
# from tensorflow.keras.applications import VGG16
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization, GlobalAveragePooling2D, Input
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# from tensorflow.keras import backend as K

# # ✅ Clear old model
# K.clear_session()

# # Load VGG16
# base_model = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# # Freeze layers
# for layer in base_model.layers:
#     layer.trainable = False

# # Add custom layers
# x = base_model.output
# x = GlobalAveragePooling2D()(x)
# x = Dense(512, activation='relu')(x)
# x = BatchNormalization()(x)
# x = Dropout(0.5)(x)
# x = Dense(128, activation='relu')(x)
# x = Dropout(0.3)(x)

# # ✅ FINAL FIX — output 4 classes instead of 3
# output = Dense(4, activation='softmax')(x)

# # Create model
# model = Model(inputs=base_model.input, outputs=output)

# # Compile
# model.compile(
#     optimizer=Adam(learning_rate=0.0001),
#     loss='categorical_crossentropy',
#     metrics=['accuracy']
# )

# # ✅ Confirm shape
# print("✅ Output shape:", model.output_shape)  # Must be (None, 4)

# %%
# x

# %% [markdown]
# # Summary

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %% [markdown]
# # Unfreeze last 4 convolutional layers

# %%
for layer in base_model.layers[-4:]:
    layer.trainable = True

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, zoom_range=0.2,
                                   shear_range=0.2, horizontal_flip=True, validation_split=0.2)

train_generator = train_datagen.flow_from_directory(
    "C:\\Users\\Guru\\brain tumor detection model\\dataset_split\\train",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    "C:\\Users\\Guru\\brain tumor detection model\\dataset_split\\train",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 14544 images belonging to 4 classes.
# Found 3632 images belonging to 4 classes.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Save best model based on validation accuracy
checkpoint = ModelCheckpoint(
    filepath='best_model.h5',        # Path to save the model
    monitor='val_accuracy',          # Metric to monitor
    save_best_only=True,             # Save only if val_accuracy improves
    save_weights_only=False,         # Save full model (structure + weights)
    mode='max',                      # Maximize val_accuracy
    verbose=1                        # Show message when saving
)

# Optional: Stop early if no improvement
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=5,                      # Stop after 5 epochs with no improvement
    restore_best_weights=True,
    verbose=1
)

# %% [markdown]
# # Train the model

# %%
import time  # ✅ Don't forget this!

start_time = time.time()

hs = model.fit(
    train_generator,
    steps_per_epoch=50,
    epochs=30,
    validation_data=val_generator,
    validation_steps=50,
    callbacks=[checkpoint, early_stop]
)

end_time = time.time()

print("Training Time (minutes):", (end_time - start_time) / 60)
# Out:
# C:\Users\Guru\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# C:\Users\Guru\anaconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - accuracy: 0.4652 - loss: 1.3301
# Epoch 1: val_accuracy improved from -inf to 0.53375, saving model to best_model.h5
# ...

# %%
import matplotlib.pyplot as plt

# Assuming hs is the history dict
plt.plot(hs['accuracy'], label='Train Accuracy')
plt.plot(hs['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training vs Validation Accuracy')
plt.show()

# %%
plt.plot(hs['loss'],c='red')

plt.plot(hs['val_loss'])

plt.title(' Loss VS Valid_Loss')

plt.show()

# %%
from keras.models import load_model

# %%
import os; print("bestmodel.keras" in os.listdir())
# Out:
# False

# %%
import os; print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'app.py', 'best_model.h5', 'Brain tumor detection model Report', 'BRAIN TUMOR DETECTION PPT.pptx', 'Brain Tumor Detection.ipynb', 'data set', 'dataset_split', 'picture']

# %%
from keras.preprocessing.image import load_img,img_to_array

# %%
import numpy as np

#path = "C:\\Users\\Guru\\brain tumor detection model\\dataset_split\\test\\glioma\\Tr-gl_0044.jpg"
path="C:\\Users\\Guru\\brain tumor detection model\\dataset_split\\train\\glioma\\aug_0_3.jpg"

img = load_img(path,target_size = (224,224))
input_arr = img_to_array(img)/255 # /255 to normalise the image

input_arr = np.expand_dims(input_arr,axis = 0)
pred = model.predict(input_arr)[0][0]

pred

if(pred == 0):
  print(" The MRI image has a tumor")
else :
  print(" The MRI image is a Healthy image")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step
#  The MRI image is a Healthy image
